# %%
#モジュールの用意
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

#ログイン用の設定
connection_config = {
    'user': 'postgres',
    'password':  'kuma_aso_3',
    'host': '127.0.0.1',
    'port': '5432',
    'database': 'test.ESI'
}

#データベースへ接続
engine = create_engine('postgresql://{user}:{password}\
@{host}:{port}/{database}'.format(**connection_config))

# %%
df = pd.read_sql(sql = "select * from blogpost_esi_descriptor_model", con=engine )
df.head()
# Out:
#    id                         compound_name                        smiles  \
# 0   1  2,6-dichloro-N-pyridin-4-ylbenzamide  O=C(Nc1ccncc1)c1c(Cl)cccc1Cl
# 1   2               N-pyridin-4-ylbenzamide        O=C(Nc1ccncc1)c1ccccc1
# 2   3      2-chloro-N-pyridin-4-ylbenzamide      O=C(Nc1ccncc1)c1ccccc1Cl
#
#         lpv      c_s0      s0_c       eav      a_s0      s0_a       stv  \
# 0  9.000907  0.349760  0.330798 -0.573400  0.759747  0.926604  4.621081
# 1  8.840427  0.328788  0.274675 -0.289517  0.347465  0.360118  4.489699
# 2  8.852148  0.325323  0.280902 -0.109846  0.367324  0.428913  4.445861
#
#       t1_s0     s0_t1     esolv      dm     vmol    b1    b2    b3
# 0  2.035127  1.144559 -0.372608  5.9631  167.979  None  None  None
# 1  1.583510  0.611116 -0.343112  5.2098  142.783  None  None  None
# 2  0.537189  0.510195 -0.300384  5.3339  153.937  None  None  None

# %%
SMILES="O=C(Nc1ccncc1)c1ccccc1Cl"

# %%
query="select * from blogpost_esi_descriptor_model WHERE smiles="+"'"+SMILES+"';"
data1 = pd.read_sql(sql = query, con=engine )
data1.head()
# Out:
#    id                     compound_name                    smiles       lpv  \
# 0   3  2-chloro-N-pyridin-4-ylbenzamide  O=C(Nc1ccncc1)c1ccccc1Cl  8.852148
#
#        c_s0      s0_c       eav      a_s0      s0_a       stv     t1_s0  \
# 0  0.325323  0.280902 -0.109846  0.367324  0.428913  4.445861  0.537189
#
#       s0_t1     esolv      dm     vmol    b1    b2    b3
# 0  0.510195 -0.300384  5.3339  153.937  None  None  None

# %%
# !pwd
# Out:
# /Users/uchidayuki/Desktop/ESIdatabase/練習用/blogpost

# %%
xyz = pd.read_csv('../rdkit/smiles.csv')
asd=xyz.iloc[:,1]
smiles=[]
for i in range(len(asd)):
    B=xyz.iloc[i, 1]
    smiles.append(B)

# %%
smiles
# Out:
# ['O=C(Nc1ccncc1)c1c(Cl)', 'O=C(Nc1ccncc1)c1ccccc1', 'O=C(Nc1ccncc1)c1ccccc1Cl']

# %%
data2 = pd.DataFrame()
for x in range (len(asd)):
    query="select * from blogpost_esi_descriptor_model WHERE smiles="+"'"+smiles[x]+"';"
    data1 = pd.read_sql(sql = query, con=engine )
    data2 = pd.concat([data2, data1], ignore_index=True)

# %%
xyz
# Out:
#                              compd_name                    smiles
# 0  2,6-dichloro-N-pyridin-4-ylbenzamide     O=C(Nc1ccncc1)c1c(Cl)
# 1               N-pyridin-4-ylbenzamide    O=C(Nc1ccncc1)c1ccccc1
# 2      2-chloro-N-pyridin-4-ylbenzamide  O=C(Nc1ccncc1)c1ccccc1Cl

# %%
ESI=pd.merge(xyz, data2, on='smiles', how='left')

# %%
ESI
# Out:
#                              compd_name                    smiles   id  \
# 0  2,6-dichloro-N-pyridin-4-ylbenzamide     O=C(Nc1ccncc1)c1c(Cl)  NaN
# 1               N-pyridin-4-ylbenzamide    O=C(Nc1ccncc1)c1ccccc1    2
# 2      2-chloro-N-pyridin-4-ylbenzamide  O=C(Nc1ccncc1)c1ccccc1Cl    3
#
#                       compound_name       lpv      c_s0      s0_c       eav  \
# 0                               NaN       NaN       NaN       NaN       NaN
# 1           N-pyridin-4-ylbenzamide  8.840427  0.328788  0.274675 -0.289517
# 2  2-chloro-N-pyridin-4-ylbenzamide  8.852148  0.325323  0.280902 -0.109846
#
#        a_s0      s0_a       stv     t1_s0     s0_t1     esolv      dm  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN     NaN
# 1  0.347465  0.360118  4.489699   1.58351  0.611116 -0.343112  5.2098
# 2  0.367324  0.428913  4.445861  0.537189  0.510195 -0.300384  5.3339
#
#       vmol    b1    b2    b3
# 0      NaN   NaN   NaN   NaN
# 1  142.783  None  None  None
# 2  153.937  None  None  None

# %%
ESI.to_csv('../ESI_to_user/rdkit_descriptor.csv', index=False)

# %%
xyz
# Out:
#                              compd_name                    smiles
# 0  2,6-dichloro-N-pyridin-4-ylbenzamide     O=C(Nc1ccncc1)c1c(Cl)
# 1               N-pyridin-4-ylbenzamide    O=C(Nc1ccncc1)c1ccccc1
# 2      2-chloro-N-pyridin-4-ylbenzamide  O=C(Nc1ccncc1)c1ccccc1Cl

# %%
ESI=ESI.drop('id', axis=1)
ESI
# Out:
#                              compd_name                    smiles  \
# 0  2,6-dichloro-N-pyridin-4-ylbenzamide     O=C(Nc1ccncc1)c1c(Cl)
# 1               N-pyridin-4-ylbenzamide    O=C(Nc1ccncc1)c1ccccc1
# 2      2-chloro-N-pyridin-4-ylbenzamide  O=C(Nc1ccncc1)c1ccccc1Cl
#
#                       compound_name       lpv      c_s0      s0_c       eav  \
# 0                               NaN       NaN       NaN       NaN       NaN
# 1           N-pyridin-4-ylbenzamide  8.840427  0.328788  0.274675 -0.289517
# 2  2-chloro-N-pyridin-4-ylbenzamide  8.852148  0.325323  0.280902 -0.109846
#
#        a_s0      s0_a       stv     t1_s0     s0_t1     esolv      dm  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN     NaN
# 1  0.347465  0.360118  4.489699   1.58351  0.611116 -0.343112  5.2098
# 2  0.367324  0.428913  4.445861  0.537189  0.510195 -0.300384  5.3339
#
#       vmol    b1    b2    b3
# 0      NaN   NaN   NaN   NaN
# 1  142.783  None  None  None
# 2  153.937  None  None  None

# %%
print(type(ESI))
# Out:
# <class 'pandas.core.frame.DataFrame'>
